# %% [markdown]
# <a href="https://colab.research.google.com/github/twyeh/highenergy/blob/main/QCD_Modified_Parton_Model_in_Exclusive_Processes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # QCD Modified Parton Model
# The concpet of partons arises for identifing point like objects conatined inside a hadron, which undertakes in a hard scattering process probed by one incoming (or out-going) high energetic simple particle, such as an electron.
# The typical example is the deep inelastic scattering (DIS) for one electron $e^-$bombing the target proton $p^+$ $e^- p^+$. The cross section could be described as
# $$
# \begin{equation}
# \frac{d\sigma}{d\Omega}=(\frac{d\sigma}{d\Omega})_{\text{Mott}}()
# \end{equation}
# $$
# ![螢幕擷取畫面 2024-10-12 125814.png](data:image/png;base64,...)
