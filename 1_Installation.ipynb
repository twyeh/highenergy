# %% [markdown]
# <a href="https://colab.research.google.com/github/twyeh/highenergy/blob/main/1_Installation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img style="float:left;margin-right:1em;width:5em;" src="img/flavio.svg">
#
# # flavio: a Python package for flavour phenomenology & more
#
# <div style="clear:left;"></div>
#
# A tutorial  (by David M. Straub)
#
# - `flavio` docs: https://flav-io.github.io
# - `flavio` source: https://github.com/flav-io/flavio
# - This tutorial: https://github.com/DavidMStraub/flavio-tutorial

# %% [markdown]
# ## Preliminary remarks
#
# - You can run this entire tutorial presentation with live code execution in your browser by navigating to <https://goo.gl/VMD3YD>
# - This is made possible by a number of great projects:
#     - [Jupyter](http://jupyter.org/)
#     - [Binder](https://mybinder.org/)
#     - [reaveal.js](https://revealjs.com/)
#     - [RISE](https://github.com/damianavila/RISE)

# %% [markdown]
# ### Navigating the slides
#
# - <kbd>PgUp</kbd> or <kbd>Space</kbd>: next slide
# - <kbd>PgDn</kbd> or <kbd>Shift</kbd> + <kbd>Space</kbd>: previous slide
# - <kbd>w</kbd>: overview mode
# - <kbd>Shift</kbd> + <kbd>Enter</kbd>: execute cell
# - <kbd>Enter</kbd>: edit cell

# %% [markdown]
# ## flavio: what can it do for me?
#
# ### 1. Predictions
#
# - Standard Model predictions (with uncertainties) for a huge number of observables in flavour physics
# - Predictions in the presence of new physics (parametrized as Wilson coefficient values)
# - interface to model-specific Wilson coefficient calculators

# %% [markdown]
# ### 2. Fits
#
# - Fit parameters (e.g. CKM parameters) or Wilson  coefficients to existing experimental data
# - Bayesian or frequentist statistics
# - various fitters  & interfaces to external fitters

# %% [markdown]
# ### 3. Plots
#
# - Visualize experimental measurements & theory predictions
# - Visualize your fit results

# %% [markdown]
# ## Showcase
#
# Frequentist & Bayesian fits of $V_{cb}$ in the SM ([arXiv:1801.01112](https://arxiv.org/abs/1801.01112))
#
# ![](img/Vcb.svg)

# %% [markdown]
# New physics in $b\to s\ell^+\ell^-$  ([arXiv:1703.09189](https://arxiv.org/abs/1703.09189))
#
# ![](img/C9-C10_allExperiments.svg)

# %% [markdown]
# SM vs. NP in $B\to D^*\ell\nu$ ([arXiv:1801.01112](https://arxiv.org/abs/1801.01112))
#
# ![](img/CSL_q2.svg)

# %% [markdown]
# For more papers using flavio (not only by flavio developers!), see
#
# <https://flav-io.github.io/papers.html>

# %% [markdown]
# ## Ways of running flavio
#
# - interactively using Jupyter (or IPython)
# - as a script
# - on a supercomputer using parallelization (multithreading, MPI)
# - as a library in your own Python code

# %% [markdown]
# ## Installing flavio
#
# ### Setting up Python
#
# To install flavio, you need Python 3.5 or above as well as pip
#
# (press Shift + Enter to execute this cell):

# %%
! python3 --version
! pip3 --version

# %% [markdown]
# All set? If not, more options below

# %% [markdown]
# ### I don't have Python yet
#
# - Ubuntu 16.04 or newer:
#
# ```bash
# sudo apt install python3 python3-pip```
#
# - MaC OS:
#
# ```bash
# brew install python3```
#
# NB: this will not interfere with your Python 2.7 installation!

# %% [markdown]
# ### I use Windows
#
# or
#
# ### I use an ancient Linux with Python 3.(x<5)
#
# &rarr; Use Anaconda/Miniconda

# %% [markdown]
# ### Using Miniconda
#
# - Anaconda is a Python distribution with its own package manager (`conda`)
# - It works on Linux, Mac OS, and Windows
# - Miniconda is the minimal version just installing Python, `conda`, and `pip`
# - Download the installer from <https://conda.io/miniconda.html>

# %% [markdown]
# ## Installing the flavio package
#
# This is now as simple as:
#
# ```bash
# pip3 install flavio --user
# ```
#
# To upgrade to a new version, use
#
# ```bash
# pip3 install flavio --user --upgrade
# ```

# %%
# !pip install flavio[plotting,testing,sampling]
# Out:
# Collecting flavio[plotting,sampling,testing]
#   Downloading flavio-2.6.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting ckmutil>=1.2.0 (from flavio[plotting,sampling,testing])
#   Downloading ckmutil-1.2.0-py3-none-any.whl.metadata (858 bytes)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from flavio[plotting,sampling,testing]) (2.0.2)
# Collecting particle>=0.21.0 (from flavio[plotting,sampling,testing])
#   Downloading particle-0.25.3-py3-none-any.whl.metadata (24 kB)
# Collecting parton>=0.2.1 (from flavio[plotting,sampling,testing])
#   Downloading parton-0.2.2.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from flavio[plotting,sampling,testing]) (6.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from flavio[plotting,sampling,testing]) (1.14.1)
# Requirement already satisfied: setuptools>=3.3 in /usr/local/lib/python3.11/dist-packages (from flavio[plotting,sampling,testing]) (75.2.0)
# Collecting wilson>=2.4 (from flavio[plotting,sampling,testing])
#   Downloading wilson-2.5.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: matplotlib>=2.0 in /usr/local/lib/python3.11/dist-packages (from flavio[plotting,sampling,testing]) (3.10.0)
# Collecting iminuit>=2.0 (from flavio[plotting,sampling,testing])
#   Downloading iminuit-2.31.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting nose2 (from flavio[plotting,sampling,testing])
#   Downloading nose2-0.15.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->flavio[plotting,sampling,testing]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->flavio[plotting,sampling,testing]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->flavio[plotting,sampling,testing]) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->flavio[plotting,sampling,testing]) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->flavio[plotting,sampling,testing]) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->flavio[plotting,sampling,testing]) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->flavio[plotting,sampling,testing]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->flavio[plotting,sampling,testing]) (2.8.2)
# Requirement already satisfied: attrs>=19.2 in /usr/local/lib/python3.11/dist-packages (from particle>=0.21.0->flavio[plotting,sampling,testing]) (25.3.0)
# Collecting hepunits>=2.0.0 (from particle>=0.21.0->flavio[plotting,sampling,testing])
#   Downloading hepunits-2.3.5-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: typing-extensions>=4.5 in /usr/local/lib/python3.11/dist-packages (from particle>=0.21.0->flavio[plotting,sampling,testing]) (4.13.1)
# Collecting appdirs (from parton>=0.2.1->flavio[plotting,sampling,testing])
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from wilson>=2.4->flavio[plotting,sampling,testing]) (2.2.2)
# Collecting pylha>=0.2 (from wilson>=2.4->flavio[plotting,sampling,testing])
#   Downloading pylha-0.4.tar.gz (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rundec>=0.5 (from wilson>=2.4->flavio[plotting,sampling,testing])
#   Downloading rundec-0.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (575 bytes)
# Collecting voluptuous (from wilson>=2.4->flavio[plotting,sampling,testing])
#   Downloading voluptuous-0.15.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0->flavio[plotting,sampling,testing]) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->wilson>=2.4->flavio[plotting,sampling,testing]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->wilson>=2.4->flavio[plotting,sampling,testing]) (2025.2)
# Downloading ckmutil-1.2.0-py3-none-any.whl (11 kB)
# Downloading iminuit-2.31.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (444 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.4/444.4 kB 9.6 MB/s eta 0:00:00
# Downloading particle-0.25.3-py3-none-any.whl (290 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.5/290.5 kB 16.6 MB/s eta 0:00:00
# Downloading wilson-2.5.2-py3-none-any.whl (594 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.8/594.8 kB 24.4 MB/s eta 0:00:00
# Downloading flavio-2.6.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 23.1 MB/s eta 0:00:00
# Downloading nose2-0.15.1-py3-none-any.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.3/211.3 kB 10.5 MB/s eta 0:00:00
# Downloading hepunits-2.3.5-py3-none-any.whl (14 kB)
# Downloading rundec-0.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 40.2 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading voluptuous-0.15.2-py3-none-any.whl (31 kB)
# Building wheels for collected packages: parton, pylha
#   Building wheel for parton (setup.py) ... done
#   Created wheel for parton: filename=parton-0.2.2-py3-none-any.whl size=14000 sha256=1b7a300c16844098b1540e34210b95dc8803d1ea99ff7ed3df1e8347f71d8cbe
#   Stored in directory: /root/.cache/pip/wheels/4f/5f/ba/4a4c454a28005125067382ffc0c3e967429b658917d062d75e
#   Building wheel for pylha (setup.py) ... done
#   Created wheel for pylha: filename=pylha-0.4-py3-none-any.whl size=58269 sha256=c6cfae08b4e210bf8c0e7473d6f929bd1f8725fbabe3dd574cefae4124f6e715
#   Stored in directory: /root/.cache/pip/wheels/e5/fa/51/6cb033ac4cb2857410fa6e15c87a4501df116007d79c91b473
# Successfully built parton pylha
# Installing collected packages: rundec, appdirs, voluptuous, pylha, nose2, iminuit, hepunits, parton, particle, ckmutil, wilson, flavio
# Successfully installed appdirs-1.4.4 ckmutil-1.2.0 flavio-2.6.2 hepunits-2.3.5 iminuit-2.31.1 nose2-0.15.1 particle-0.25.3 parton-0.2.2 pylha-0.4 rundec-0.6 voluptuous-0.15.2 wilson-2.5.2

# %%
import flavio
flavio.__version__
# Out:
# '2.6.2'

# %% [markdown]
# ### Installing extras
#
# Some additional features of flavio have dependencies that are not installed by default. You can install all of them with
#
# ```bash
# pip3 install flavio[plotting,testing,sampling]
# ```
#
# Note that `sampling` installs packages that require `cython` and `numpy` to be installed first.

# %% [markdown]
# ### Tests
#
# If you want to tests whether all features of flavio work on your system, you can run all of the unit tests of the package:

# %%
# !pip install nose
# Out:
# Collecting nose
#   Downloading nose-1.3.7-py3-none-any.whl.metadata (1.7 kB)
# Downloading nose-1.3.7-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: nose
# Successfully installed nose-1.3.7

# %%
import nose

# %%
# !nosetests flavio
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/nosetests", line 8, in <module>
#     sys.exit(run_exit())
#              ^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nose/core.py", line 118, in __init__
#     unittest.TestProgram.__init__(
#   File "/usr/lib/python3.11/unittest/main.py", line 101, in __init__
#     self.parseArgs(argv)
#   File "/usr/local/lib/python3.11/dist-packages/nose/core.py", line 179, in parseArgs
#     self.createTests()
#   File "/usr/local/lib/python3.11/dist-packages/nose/core.py", line 193, in createTests
#     self.test = self.testLoader.loadTestsFromNames(self.testNames)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nose/loader.py", line 481, in loadTestsFromNames
#     return unittest.TestLoader.loadTestsFromNames(self, names, module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/unittest/loader.py", line 232, in loadTestsFromNames
#     suites = [self.loadTestsFromName(name, module) for name in names]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/unittest/loader.py", line 232, in <listcomp>
#     suites = [self.loadTestsFromName(name, module) for name in names]
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nose/loader.py", line 431, in loadTestsFromName
#     return self.loadTestsFromModule(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nose/loader.py", line 354, in loadTestsFromModule
#     tests.extend(self.loadTestsFromDir(module_path))
#   File "/usr/local/lib/python3.11/dist-packages/nose/loader.py", line 191, in loadTestsFromDir
#     yield self.loadTestsFromName(
#           ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nose/loader.py", line 431, in loadTestsFromName
#     return self.loadTestsFromModule(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nose/loader.py", line 354, in loadTestsFromModule
#     tests.extend(self.loadTestsFromDir(module_path))
#   File "/usr/local/lib/python3.11/dist-packages/nose/loader.py", line 183, in loadTestsFromDir
#     yield self.loadTestsFromName(
#           ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nose/loader.py", line 431, in loadTestsFromName
#     return self.loadTestsFromModule(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nose/loader.py", line 359, in loadTestsFromModule
#     return self.suiteClass(ContextList(tests, context=module))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nose/suite.py", line 428, in __call__
#     return self.makeSuite(tests, context, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nose/suite.py", line 475, in makeSuite
#     suite = self.suiteClass(
#             ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nose/suite.py", line 159, in __init__
#     super(ContextSuite, self).__init__(tests)
#   File "/usr/local/lib/python3.11/dist-packages/nose/suite.py", line 53, in __init__
#     super(LazySuite, self).__init__()
#   File "/usr/lib/python3.11/unittest/suite.py", line 22, in __init__
#     self._tests = []
#     ^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nose/suite.py", line 106, in _set_tests
#     if isinstance(tests, collections.Callable) and not is_suite:
#                          ^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'collections' has no attribute 'Callable'

# %% [markdown]
# Unit tests play an important role in making the code as reliable as possible and making development easier

# %% [markdown]
# (If the `nosetests` command doesn't work on your system, try running `python3 -m nose flavio` instead)

# %% [markdown]
# ### Installing Jupyter & IPython
#
# ```bash
# pip3 install ipython jupyter --user
# ```
#
# ... and the run it:
#
# ```bash
# jupyter notebook
# ```
# or if you prefer an interactive terminal session:
# ```bash
# ipython3
# ```

# %% [markdown]
# ### Getting help
#
# - An introductory documentation can be found at <https://flav-io.github.io/docs/>
# - Detailed documentation of all functions and classes at <https://flav-io.github.io/apidoc/flavio/>
# - Jupyter/IPython: use auto-completion and `?`

# %% [markdown]
# ### Outline
#
# 1. Motivation and Installation
# 2. [Basic concepts](2 Basic concepts.ipynb) (observables, predictions, parameters, measurements)
# 3. [Wilson coefficients](3 Wilson coefficients.ipynb) (physics beyond the Standard Model)
# 4. [Fits](4 Fits.ipynb) (statistical inference)
# 5. [Extending flavio](5 Extending.ipynb) (adding new observables)
